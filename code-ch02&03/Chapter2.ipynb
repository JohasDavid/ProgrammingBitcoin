# %%
from ecc import Point

# %%
p1 = Point(-1, -1, 5, 7)
p2 = Point(-1, -2, 5, 7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 p1 = Point(-1, -1, 5, 7)
# ----> 2 p2 = Point(-1, -2, 5, 7)
#
# File ~/Desktop/code/myprogrammingbitcoin/code-ch02/ecc.py:71, in Point.__init__(self, x, y, a, b)
#      69     return
#      70 if self.y ** 2 != (self.x ** 3) + (a * x) + b:
# ---> 71     raise ValueError(f"({x}, {y}) is not in the curve")
#
# ValueError: (-1, -2) is not in the curve
