# %%
import ecc
from helper import run
run(ecc.ECCTest('test_on_curve'))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %%
import ecc
from helper import run
run(ecc.ECCTest('test_add'))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.004s
#
# OK
# Point(FieldElement(220)_223, FieldElement(181)_223)
# Point(FieldElement(215)_223, FieldElement(68)_223)
# Point(FieldElement(47)_223, FieldElement(71)_223)
