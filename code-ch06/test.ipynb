# %%
from script import Script
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from script import Script
#
# File ~/Desktop/code/myprogrammingbitcoin/code-ch06/script.py:2
#       1 from helper import hash256, hash160, read_varint,little_endian_to_int, int_to_little_endian, encode_varint
# ----> 2 from op import OP_CODE_FUNCTIONS, OP_CODE_NAMES
#       3 def op_dup(stack):
#       4     if len(stack) < 1:
#
# File ~/Desktop/code/myprogrammingbitcoin/code-ch06/op.py:2
#       1 OP_CODE_FUNCTIONS = {
# ----> 2     0: op_0,
#       3     79: op_1negate,
#       4     81: op_1,
#       5     82: op_2,
#       6     83: op_3,
#       7     84: op_4,
#       8     85: op_5,
#       9     86: op_6,
#      10     87: op_7,
#      11     88: op_8,
#      12     89: op_9,
#      13     90: op_10,
#      14     91: op_11,
#      15     92: op_12,
#      16     93: op_13,
#      17     94: op_14,
#      18     95: op_15,
#      19     96: op_16,
#      20     97: op_nop,
#      21     99: op_if,
#      22     100: op_notif,
#      23     105: op_verify,
#      24     106: op_return,
#      25     107: op_toaltstack,
#      26     108: op_fromaltstack,
#      27     109: op_2drop,
#      28     110: op_2dup,
#      29     111: op_3dup,
#      30     112: op_2over,
#      31     113: op_2rot,
#      32     114: op_2swap,
#      33     115: op_ifdup,
#      34     116: op_depth,
#      35     117: op_drop,
#      36     118: op_dup,
#      37     119: op_nip,
#      38     120: op_over,
#      39     121: op_pick,
#      40     122: op_roll,
#      41     123: op_rot,
#      42     124: op_swap,
#      43     125: op_tuck,
#      44     130: op_size,
#      45     135: op_equal,
#      46     136: op_equalverify,
#      47     139: op_1add,
#      48     140: op_1sub,
#      49     143: op_negate,
#      50     144: op_abs,
#      51     145: op_not,
#      52     146: op_0notequal,
#      53     147: op_add,
#      54     148: op_sub,
#      55     149: op_mul,
#      56     154: op_booland,
#      57     155: op_boolor,
#      58     156: op_numequal,
#      59     157: op_numequalverify,
#      60     158: op_numnotequal,
#      61     159: op_lessthan,
#      62     160: op_greaterthan,
#      63     161: op_lessthanorequal,
#      64     162: op_greaterthanorequal,
#      65     163: op_min,
#      66     164: op_max,
#      67     165: op_within,
#      68     166: op_ripemd160,
#      69     167: op_sha1,
#      70     168: op_sha256,
#      71     169: op_hash160,
#      72     170: op_hash256,
#      73     172: op_checksig,
#      74     173: op_checksigverify,
#      75     174: op_checkmultisig,
#      76     175: op_checkmultisigverify,
#      77     176: op_nop,
#      78     177: op_checklocktimeverify,
#      79     178: op_checksequenceverify,
#      80     179: op_nop,
#      81     180: op_nop,
#      82     181: op_nop,
#      83     182: op_nop,
#      84     183: op_nop,
#      85     184: op_nop,
#      86     185: op_nop,
#      87 }
#      89 OP_CODE_NAMES = {
#      90     0: 'OP_0',
#      91     76: 'OP_PUSHDATA1',
#    (...)    180     185: 'OP_NOP10',
#     181 }
#
# NameError: name 'op_0' is not defined

# %%
z = 0x7c076ff316692a3d7eb3c3bb0f8b1488cf72e1afcd929e29307032997a838a3d
sec = bytes.fromhex('04887387e452b8eacc4acfde10d9aaf7f6d9a0f975aabb10d006e\
4da568744d06c61de6d95231cd89026e286df3b6ae4a894a3378e393e93a0f45b666329a0ae34')
sig = bytes.fromhex('3045022000eff69ef2b1bd93a66ed5219add4fb51e11a840f4048\
76325a1e8ffe0529a2c022100c7207fee197d27c618aea621406f6bf5ef6fca38681d82b2f06fd\
dbdce6feab601')
script_pubkey = Script([sec, 0xac])
script_sig = Script([sig])
combined_script = script_sig + script_pubkey
print(combined_script.evaluate(z))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 10
#       8 script_sig = Script([sig])
#       9 combined_script = script_sig + script_pubkey
# ---> 10 print(combined_script.evaluate(z))
#
# AttributeError: 'Script' object has no attribute 'evaluate'
